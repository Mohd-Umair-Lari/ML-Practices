# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model=Sequential()

model.add(Dense(2,input_dim=2,activation='linear'))
model.add(Dense(1,activation='linear'))
# Out:
# c:\Users\umair\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Remember the keras initializes random weights instead of 0.1 or baby weights

# %%
model.get_weights()
# Out:
# [array([[0.9608537 , 0.12359333],
#         [1.0574905 , 1.0868553 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.6506674],
#         [ 1.0699774]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer=keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=optimizer,loss='mean_squared_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
X=df[['cgpa','profile_score']]
y=df[['lpa']]

model.fit(X,y,epochs=75,verbose=1)
# Out:
# Epoch 1/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0731
# Epoch 2/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0711
# Epoch 3/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.0695
# Epoch 4/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0683
# Epoch 5/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0675
# Epoch 6/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0672
# Epoch 7/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0670
# Epoch 8/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0668
# Epoch 9/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0665
# Epoch 10/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0660
# Epoch 11/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0652
# Epoch 12/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - loss: 0.0643
# Epoch 13/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0633
# Epoch 14/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0623
# Epoch 15/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0614
# Epoch 16/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0606
# Epoch 17/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0600
# Epoch 18/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0596
# Epoch 19/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0591
# Epoch 20/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 0.0587
# Epoch 21/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0583
# Epoch 22/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0578
# Epoch 23/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0572
# Epoch 24/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0566
# Epoch 25/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0559
# Epoch 26/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0553
# Epoch 27/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0547
# Epoch 28/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0542
# Epoch 29/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0537
# Epoch 30/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0533
# Epoch 31/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0528
# Epoch 32/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0524
# Epoch 33/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0520
# Epoch 34/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0515
# Epoch 35/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0511
# Epoch 36/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.0506
# Epoch 37/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0502
# Epoch 38/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0497
# Epoch 39/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0493
# Epoch 40/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0489
# Epoch 41/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0485
# Epoch 42/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0481
# Epoch 43/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0477
# Epoch 44/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0474
# Epoch 45/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0470
# Epoch 46/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0466
# Epoch 47/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0463
# Epoch 48/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0459
# Epoch 49/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0456
# Epoch 50/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0452
# Epoch 51/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0449
# Epoch 52/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0446
# Epoch 53/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0443
# Epoch 54/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0439
# Epoch 55/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0436
# Epoch 56/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0433
# Epoch 57/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0430
# Epoch 58/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0428
# Epoch 59/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0425
# Epoch 60/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0422
# Epoch 61/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0419
# Epoch 62/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0417
# Epoch 63/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0414
# Epoch 64/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0411
# Epoch 65/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0409
# Epoch 66/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0406
# Epoch 67/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0404
# Epoch 68/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0402
# Epoch 69/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0399
# Epoch 70/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0397
# Epoch 71/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0395
# Epoch 72/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0393
# Epoch 73/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0391
# Epoch 74/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0389
# Epoch 75/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0387

# %%
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
