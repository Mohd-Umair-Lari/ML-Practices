# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv('fashionmnisttrain.csv')

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

val_data = train_data.iloc[:5000,:]
test_data = train_data.iloc[5000:,:]

train_labels = train_data.label
val_labels = val_data.label
test_labels = test_data.label

train_images = train_data.iloc[:,1:].values.reshape(60000, 28, 28)

val_images = val_data.iloc[:,1:].values.reshape(5000, 28, 28)

train_images = train_images/255.0
val_images = val_images/255.0

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(1, activation=tf.keras.activations.linear),
    keras.layers.Dense(10, activation=tf.keras.activations.linear)
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(), 
    metrics=["accuracy"]
)

model1=model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# C:\Users\umair\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.1181 - loss: 6.3965 - val_accuracy: 0.1908 - val_loss: 2.7514
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1323 - loss: 2.3601 - val_accuracy: 0.1022 - val_loss: 2.3008
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.1014 - loss: 2.3016 - val_accuracy: 0.0990 - val_loss: 2.3021
# Epoch 4/5
# ...

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(10, activation=tf.keras.activations.linear),
    keras.layers.Dense(10, activation=tf.keras.activations.linear)
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(), 
    metrics=["accuracy"]
)

model2=model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.4546 - loss: 2.6505 - val_accuracy: 0.4166 - val_loss: 2.3012
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4430 - loss: 2.3018 - val_accuracy: 0.4676 - val_loss: 2.3012
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.4442 - loss: 2.3022 - val_accuracy: 0.4530 - val_loss: 2.3017
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.3530 - loss: 2.3025 - val_accuracy: 0.3496 - val_loss: 2.3026
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.3442 - loss: 2.3021 - val_accuracy: 0.3496 - val_loss: 2.3026

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(10, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(), 
    metrics=["accuracy"]
)

model3=model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.7700 - loss: 0.6852 - val_accuracy: 0.8362 - val_loss: 0.4850
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8364 - loss: 0.4759 - val_accuracy: 0.8488 - val_loss: 0.4523
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8447 - loss: 0.4442 - val_accuracy: 0.8600 - val_loss: 0.4169
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8512 - loss: 0.4281 - val_accuracy: 0.8636 - val_loss: 0.4016
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8535 - loss: 0.4193 - val_accuracy: 0.8668 - val_loss: 0.3926

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(10, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(), 
    metrics=["accuracy"]
)

model3=model.fit(train_images, train_labels, epochs=5, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - accuracy: 0.7012 - loss: 0.8189 - val_accuracy: 0.8166 - val_loss: 0.5398
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8170 - loss: 0.5245 - val_accuracy: 0.8370 - val_loss: 0.4763
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8315 - loss: 0.4822 - val_accuracy: 0.8496 - val_loss: 0.4420
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8409 - loss: 0.4569 - val_accuracy: 0.8546 - val_loss: 0.4303
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8454 - loss: 0.4441 - val_accuracy: 0.8584 - val_loss: 0.4220

# %%
matrix=np.array([
    [5,54,24,12],
    [8,68,6,16],
    [9,91,100,42]],
dtype=float)

data=pd.DataFrame(matrix,columns=['F1','F2','F3','target'])
data
# Out:
#     F1    F2     F3  target
# 0  5.0  54.0   24.0    12.0
# 1  8.0  68.0    6.0    16.0
# 2  9.0  91.0  100.0    42.0

# %%
X=data.iloc[:,:3]
y=data.iloc[:,3]

# %%
train_X=data.iloc[0:2,0:3]
test_X=data.iloc[2:3,0:3]

train_y=data.iloc[0:2,3]
test_y=data.iloc[2:3,3]

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(3,1)),
    keras.layers.Dense(3, activation=tf.keras.activations.linear),
    keras.layers.Dense(3, activation=tf.keras.activations.linear),
    keras.layers.Dense(1, activation=tf.keras.activations.linear)
])

model.compile(
    loss="mse",
    optimizer=keras.optimizers.Adam(), 
    metrics=["mae"]
)

model5=model.fit(X,y, epochs=30)
# Out:
# Epoch 1/30
# C:\Users\umair\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1141.7360 - mae: 29.6582
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1117.4602 - mae: 29.3182
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1093.4713 - mae: 28.9785
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1069.7737 - mae: 28.6391
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1046.3715 - mae: 28.3002
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1023.2686 - mae: 27.9617
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1000.4689 - mae: 27.6239
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 977.9756 - mae: 27.2866
# ...
