# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import random
import numpy as np

# %%
df=pd.read_csv('placement.csv')
X=df['cgpa'] 
y=df['package']
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(x=X,y=y)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
model=LinearRegression()
model.fit(X_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
sns.scatterplot(x=X,y=y)
sns.lineplot(x=X,y=model.predict(X.values.reshape(-1,1)),color='red')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=model.predict(X_test.values.reshape(-1,1))
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)
adjusted_r2=1-(1-r2)*(len(y)-1)/(len(y)-X.shape[0]-1)

# %%
print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)    
print("R2 Score:",r2)
print("Root Mean Squared Error:",rmse)
print("Adjusted R2 Score:",adjusted_r2)
# Out:
# Mean Squared Error: 0.12129235313495527
# Mean Absolute Error: 0.2884710931878175
# R2 Score: 0.780730147510384
# Root Mean Squared Error: 0.34827051717731616
# Adjusted R2 Score: 44.634700645433576

# %%
df['nf'] = np.random.random(len(df))

# %%
df
# Out:
#      cgpa  package        nf
# 0    6.89     3.26  0.647964
# 1    5.12     1.98  0.384578
# 2    7.82     3.25  0.219235
# 3    7.42     3.67  0.343595
# 4    6.94     3.57  0.752565
# ..    ...      ...       ...
# 195  6.93     2.46  0.251134
# 196  5.89     2.57  0.888547
# 197  7.21     3.24  0.416533
# 198  7.63     3.96  0.565450
# 199  6.22     2.33  0.252691
#
# [200 rows x 3 columns]

# %%
new_x=df[['cgpa','nf']]
new_y=df['package']

# %%
X_train,X_test,y_train,y_test = train_test_split(new_x,new_y,test_size=0.2,random_state=2)

# %%
n_model=LinearRegression()
n_model.fit(X_train,y_train)
y_pred=n_model.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mse)
adjusted_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)
print("R2 Score:",r2)
print("Root Mean Squared Error:",rmse)
print("Adjusted R2 Score:",adjusted_r2)
# Out:
# Mean Squared Error: 0.12631728060218037
# Mean Absolute Error: 0.29615181382508904
# R2 Score: 0.7716461856938998
# Root Mean Squared Error: 0.35541142441145634
# Adjusted R2 Score: 0.7593027362719484
