# %% [markdown]
# # NumPy Practices

# %%
import numpy as np

# %% [markdown]
# ### 1. Data Types and Attributes
#
# numpy's main datatype is ndarray ( n- dimensional array)

# %%
#One Dimension
#Shape (1,3)
a1 = np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
#Data Type is ndarray
type(a1)
# Out:
# numpy.ndarray

# %%
#More than one dimension 
#Shape = (2,3)

a2 = np.array([[1,2,3.5],
              [4,5,6.5]])
a2
# Out:
# array([[1. , 2. , 3.5],
#        [4. , 5. , 6.5]])

# %% [markdown]
# ### 2.Shape of the Array & Dimension

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
# Dimension of the Array
a1.ndim, a2.ndim
# Out:
# (1, 2)

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
#number of elements
a1.size
# Out:
# 3

# %% [markdown]
# ### 3. create a dataframe from a NumPy Array

# %%
import pandas as pd

df=pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.5
# 1  4.0  5.0  6.5
