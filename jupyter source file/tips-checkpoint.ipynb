# %%
import pandas as pd
import numpy as np

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

# %%
from pandas_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# C:\Users\umair\AppData\Local\Temp\ipykernel_21964\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
df=pd.read_csv("tips.csv")

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Report=ProfileReport(df)

# %%
# Report.to_file("report.html")

# %%
y=df["tip"]

# %%
X=df.drop(columns=["tip"])

# %%
lrmodel=LinearRegression()

# %%
dtmodel=DecisionTreeRegressor()

# %%
enc=OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype=np.int32)

# %%
nX=enc.fit_transform(X[["sex","smoker","day","time"]])

# %%
nX.shape
# Out:
# (244, 10)

# %%
ndf=np.array(df[["tip","size"]].values)

# %%
ndf.shape
# Out:
# (244, 2)

# %%
new_X = np.hstack((ndf, nX))

# %%
X_train, X_test, y_train, y_test=train_test_split(new_X,y)

# %%
lrmodel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
ylr=lrmodel.predict(X_test)

# %%
ydt=dtmodel.predict(X_test)

# %%
ydt
# Out:
# array([1.5 , 3.21, 3.11, 4.  , 3.  , 1.5 , 1.67, 2.5 , 2.  , 4.2 , 2.31,
#        4.  , 4.  , 2.24, 2.74, 6.73, 3.  , 3.07, 2.  , 3.51, 2.75, 6.  ,
#        2.  , 3.06, 1.  , 4.  , 4.08, 1.  , 2.55, 2.  , 3.6 , 3.76, 1.  ,
#        3.  , 5.  , 3.5 , 2.5 , 3.5 , 5.14, 2.5 , 3.  , 1.17, 2.  , 3.5 ,
#        3.35, 2.  , 5.  , 3.35, 1.5 , 3.  , 3.  , 5.92, 2.  , 4.29, 5.  ,
#        3.25, 2.31, 1.5 , 4.  , 6.73, 2.  ])

# %%
y_test
# Out:
# 117    1.50
# 9      3.23
# 7      3.12
# 15     3.92
# 227    3.00
#        ...
# 25     2.34
# 99     1.50
# 200    4.00
# 23     7.58
# 137    2.00
# Name: tip, Length: 61, dtype: float64
