# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("tips.csv")

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
from pandas_profiling import ProfileReport
# Out:
# /tmp/ipykernel_8927/2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
from pandas_profiling import ProfileReport

# %%
Report=ProfileReport(df)

# %%
Report.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

# %%
y=df["tip"]

# %%
X=df.drop(columns=["tip"])

# %%
lrmodel=LinearRegression()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtmodel=DecisionTreeRegressor()

# %%
enc=OneHotEncoder(handle_unknown='ignore', sparse_output=False, dtype=np.int32)

# %%
nX=enc.fit_transform(X[["sex","smoker","day","time"]])

# %%
nX.shape
# Out:
# (244, 10)

# %%
ndf=np.array(df[["tip","size"]].values)

# %%
ndf.shape
# Out:
# (244, 2)

# %%
new_X = np.hstack((ndf, nX))

# %%
X_train, X_test, y_train, y_test=train_test_split(new_X,y)

# %%
lrmodel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
ylr=lrmodel.predict(X_test)

# %%
ydt=dtmodel.predict(X_test)

# %%
lrscore=accuracy_score(y_test,ylr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 lrscore=accuracy_score(y_test,ylr)
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
# ...

# %%
print("Accuracy of linear regression :", accuracy_score(y_test,ylr))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print("Accuracy of linear regression :", accuracy_score(y_test,ylr))
#
# File ~/anaconda3/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
# ...
